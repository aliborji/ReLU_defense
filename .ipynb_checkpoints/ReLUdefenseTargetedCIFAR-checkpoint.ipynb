# %%
from __future__ import print_function
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
import numpy as np
import matplotlib.pyplot as plt

import os
import sys

from torch.utils.data import DataLoader, TensorDataset

import torchvision.utils
from torchvision import models
import torchvision.datasets as dsets
import torchvision.transforms as transforms

# import torchattacks
# from torchattacks import PGD
import matplotlib.pyplot as plt

# %%
# from torchattacks import RPGD

# %%
# epsilons = [0, .05, .1, .15, .2, .25, .3]
pretrained_model = '/gdrive/My Drive/Tmp/cifar_net.pth' #pretrained_model = "lenet_mnist_model.pth"
use_cuda=True

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /gdrive

# %%
# simply define a silu function
def srelu(input, slope):
    return slope * F.relu(input)

class SReLU(nn.Module):
    def __init__(self):
        super().__init__() # init the base class

    def forward(self, input, slope):
        return srelu(input, slope) # simply apply already implemented SiLU

# %%
class Net(nn.Module):
    def __init__(self, slope):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(3, 6, 5)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(6, 16, 5)
        self.fc1 = nn.Linear(16 * 5 * 5, 120)
        self.fc2 = nn.Linear(120, 84)
        self.fc3 = nn.Linear(84, 10)
        self.slope = slope

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = x.view(-1, 16 * 5 * 5)
        x = srelu(self.fc1(x), self.slope)
        x = srelu(self.fc2(x), self.slope)
        x = self.fc3(x)
        return x


# Define what device we are using
print("CUDA Available: ",torch.cuda.is_available())
device = torch.device("cuda" if (use_cuda and torch.cuda.is_available()) else "cpu")

# # Initialize the network
# model = Net().to(device)

# # Load the pretrained model
# model.load_state_dict(torch.load(pretrained_model, map_location='cpu'))

# # Set the model in evaluation mode. In this case this is for the Dropout layers
# model.eval()
# Out:
# CUDA Available:  True

# %%
transform = transforms.Compose( 
    [transforms.ToTensor()]) 


# cifar10_train = dsets.CIFAR10(root='./data', train=True,
#                                        download=True, transform=transform)
cifar10_test  = dsets.CIFAR10(root='./data', train=False,
                                       download=True, transform=transform)


test_loader = torch.utils.data.DataLoader(cifar10_test, batch_size=1,
                                        shuffle=False, num_workers=1)


classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# Extracting ./data/cifar-10-python.tar.gz to ./data

# %%
# FGSM attack code
def fgsm_attack(image, epsilon, data_grad):
    # Collect the element-wise sign of the data gradient
    sign_data_grad = data_grad.sign()
    # Create the perturbed image by adjusting each pixel of the input image
    perturbed_image = image + epsilon*sign_data_grad
    # Adding clipping to maintain [0,1] range
    perturbed_image = torch.clamp(perturbed_image, 0, 1)
    # Return the perturbed image
    return perturbed_image

# %%
def test( model, device, test_loader, epsilon, myTarget):

    # Accuracy counter
    correct = 0
    adv_examples = []

    # Loop over all examples in test set
    # import pdb; pdb.set_trace()
    for data, target in test_loader:

        # Send the data and label to the device
        data, target, myTarget = data.to(device), target.to(device), myTarget.to(device)

        # Set requires_grad attribute of tensor. Important for Attack
        data.requires_grad = True

        # Forward pass the data through the model
        output = model(data)
        init_pred = output.max(1, keepdim=True)[1] # get the index of the max log-probability

        if init_pred.item() == myTarget.item():            
            continue

        # Calculate the loss
        # loss = F.nll_loss(output, target)

        loss = F.nll_loss(output, myTarget)        

        # Zero all existing gradients
        model.zero_grad()

        # Calculate gradients of model in backward pass
        loss.backward()

        # Collect datagrad
        data_grad = data.grad.data

        # Call FGSM Attack
        perturbed_data = fgsm_attack(data, epsilon, -1*data_grad)

        # Re-classify the perturbed image
        output = model(perturbed_data)

        # Check for success
        final_pred = output.max(1, keepdim=True)[1] # get the index of the max log-probability
        if final_pred.item() == myTarget.item():
            correct += 1
            # Special case for saving 0 epsilon examples
            if (len(adv_examples) < 5):
                adv_ex = perturbed_data.squeeze().detach().cpu().numpy()
                adv_examples.append( (init_pred.item(), final_pred.item(), adv_ex) )
#         else:
#             # Save some adv examples for visualization later
#             if len(adv_examples) < 5:
#                 adv_ex = perturbed_data.squeeze().detach().cpu().numpy()
#                 adv_examples.append( (init_pred.item(), final_pred.item(), adv_ex) )

    # Calculate final accuracy for this epsilon
    final_acc = correct/float(len(test_loader))
    print("Epsilon: {}\tTest Accuracy = {} / {} = {}".format(epsilon, correct, len(test_loader), final_acc))

    # Return the accuracy and an adversarial example
    return final_acc, adv_examples

# %%
epsilons = [0.003, 0.007, 0.01, 0.05, 0.1 ]
slopes   = [.5, 1, 2, 5, 10, 100]
symbs = ['*-', 'o-', 's-', 'd-', '+-', 'x-', '^-', '<-']


all_all_accuracies = []

for num in range(10):

    all_accuracies = []
    all_examples = []

    # Run test for each slope
    for sl in slopes:
        print(f'\n Running class={classes[num]} slope={sl} ... ')
        # Initialize the network
        model = Net(sl).to(device)

        # Load the pretrained model
        model.load_state_dict(torch.load(pretrained_model, map_location='cpu'))

        # Set the model in evaluation mode. In this case this is for the Dropout layers
        model.eval()

        # Run test for each epsilon
        def_accuracies = []
        def_examples = []
    #     myTarget = torch.tensor([2])    
        for eps in epsilons:
            myTarget = torch.tensor([num]) #torch.randint(10, (1,1)).squeeze(0)        
    #         myTarget = torch.randint(10, (1,1)).squeeze(0)                
            acc, ex = test(model, device, test_loader, eps, myTarget)
            def_accuracies.append(acc)
#             def_examples.append(ex)

        all_accuracies.append(def_accuracies)
#         all_examples.append(def_examples)

    all_all_accuracies.append(all_accuracies)
    
    all_accuracies = np.array(all_accuracies)
    # all_accuracies = all_accuracies.T    
    fig =plt.figure(figsize=(5,5))
    for idx in range(len(all_accuracies)):
        plt.plot(all_accuracies[idx,:], symbs[idx])

    #     plt.plot(epsilons, np.array(all_accuracies).T, "*-")
    plt.yticks(np.arange(0, .5, step=0.1))
    plt.xticks(np.arange(0, len(epsilons), step=1), epsilons)
    plt.title(f"Accuracy vs Epsilon (converting to {classes[num]})")
    plt.xlabel("Epsilon")
    plt.ylabel("Accuracy")
    plt.legend(slopes)
    plt.show()
    fig.savefig(f'/gdrive/My Drive/Tmp/Targeted/plot-{classes[num]}.png')

np.save(f'/gdrive/My Drive/Tmp/Targeted/CIFAR_slopes.npy', all_all_accuracies)
# Out:
#  Running class=plane slope=0.5 ...
# Epsilon: 0.003	Test Accuracy = 96 / 10000 = 0.0096
# Epsilon: 0.007	Test Accuracy = 246 / 10000 = 0.0246
# Epsilon: 0.01	Test Accuracy = 345 / 10000 = 0.0345
# Epsilon: 0.05	Test Accuracy = 1439 / 10000 = 0.1439
# Epsilon: 0.1	Test Accuracy = 1805 / 10000 = 0.1805
#
#  Running class=plane slope=1 ...
# Epsilon: 0.003	Test Accuracy = 249 / 10000 = 0.0249
# Epsilon: 0.007	Test Accuracy = 548 / 10000 = 0.0548
# Epsilon: 0.01	Test Accuracy = 763 / 10000 = 0.0763
# Epsilon: 0.05	Test Accuracy = 2373 / 10000 = 0.2373
# Epsilon: 0.1	Test Accuracy = 2716 / 10000 = 0.2716
#
#  Running class=plane slope=2 ...
# Epsilon: 0.003	Test Accuracy = 299 / 10000 = 0.0299
# Epsilon: 0.007	Test Accuracy = 664 / 10000 = 0.0664
# Epsilon: 0.01	Test Accuracy = 912 / 10000 = 0.0912
# Epsilon: 0.05	Test Accuracy = 2683 / 10000 = 0.2683
# Epsilon: 0.1	Test Accuracy = 2880 / 10000 = 0.288
#
#  Running class=plane slope=5 ...
# Epsilon: 0.003	Test Accuracy = 350 / 10000 = 0.035
# Epsilon: 0.007	Test Accuracy = 726 / 10000 = 0.0726
# Epsilon: 0.01	Test Accuracy = 1034 / 10000 = 0.1034
# Epsilon: 0.05	Test Accuracy = 2786 / 10000 = 0.2786
# Epsilon: 0.1	Test Accuracy = 2968 / 10000 = 0.2968
#
#  Running class=plane slope=10 ...
# Epsilon: 0.003	Test Accuracy = 369 / 10000 = 0.0369
# Epsilon: 0.007	Test Accuracy = 750 / 10000 = 0.075
# Epsilon: 0.01	Test Accuracy = 1064 / 10000 = 0.1064
# Epsilon: 0.05	Test Accuracy = 2813 / 10000 = 0.2813
# Epsilon: 0.1	Test Accuracy = 2998 / 10000 = 0.2998
#
#  Running class=plane slope=100 ...
# Epsilon: 0.003	Test Accuracy = 365 / 10000 = 0.0365
# Epsilon: 0.007	Test Accuracy = 772 / 10000 = 0.0772
# Epsilon: 0.01	Test Accuracy = 1096 / 10000 = 0.1096
# Epsilon: 0.05	Test Accuracy = 2787 / 10000 = 0.2787
# Epsilon: 0.1	Test Accuracy = 2994 / 10000 = 0.2994
#  Running class=car slope=0.5 ...
# Epsilon: 0.003	Test Accuracy = 134 / 10000 = 0.0134
# Epsilon: 0.007	Test Accuracy = 297 / 10000 = 0.0297
# Epsilon: 0.01	Test Accuracy = 429 / 10000 = 0.0429
# Epsilon: 0.05	Test Accuracy = 1605 / 10000 = 0.1605
# Epsilon: 0.1	Test Accuracy = 2406 / 10000 = 0.2406
#
#  Running class=car slope=1 ...
# Epsilon: 0.003	Test Accuracy = 211 / 10000 = 0.0211
# Epsilon: 0.007	Test Accuracy = 485 / 10000 = 0.0485
# Epsilon: 0.01	Test Accuracy = 707 / 10000 = 0.0707
# Epsilon: 0.05	Test Accuracy = 2487 / 10000 = 0.2487
# Epsilon: 0.1	Test Accuracy = 3438 / 10000 = 0.3438
#
#  Running class=car slope=2 ...
# Epsilon: 0.003	Test Accuracy = 246 / 10000 = 0.0246
# Epsilon: 0.007	Test Accuracy = 596 / 10000 = 0.0596
# Epsilon: 0.01	Test Accuracy = 836 / 10000 = 0.0836
# Epsilon: 0.05	Test Accuracy = 2867 / 10000 = 0.2867
# Epsilon: 0.1	Test Accuracy = 3764 / 10000 = 0.3764
#
#  Running class=car slope=5 ...
# Epsilon: 0.003	Test Accuracy = 261 / 10000 = 0.0261
# Epsilon: 0.007	Test Accuracy = 642 / 10000 = 0.0642
# Epsilon: 0.01	Test Accuracy = 929 / 10000 = 0.0929
# Epsilon: 0.05	Test Accuracy = 3016 / 10000 = 0.3016
# Epsilon: 0.1	Test Accuracy = 3829 / 10000 = 0.3829
#
#  Running class=car slope=10 ...
# Epsilon: 0.003	Test Accuracy = 271 / 10000 = 0.0271
# Epsilon: 0.007	Test Accuracy = 652 / 10000 = 0.0652
# Epsilon: 0.01	Test Accuracy = 938 / 10000 = 0.0938
# Epsilon: 0.05	Test Accuracy = 3014 / 10000 = 0.3014
# Epsilon: 0.1	Test Accuracy = 3829 / 10000 = 0.3829
#
#  Running class=car slope=100 ...
# Epsilon: 0.003	Test Accuracy = 283 / 10000 = 0.0283
# Epsilon: 0.007	Test Accuracy = 671 / 10000 = 0.0671
# Epsilon: 0.01	Test Accuracy = 954 / 10000 = 0.0954
# Epsilon: 0.05	Test Accuracy = 3034 / 10000 = 0.3034
# Epsilon: 0.1	Test Accuracy = 3834 / 10000 = 0.3834
#  Running class=bird slope=0.5 ...
# Epsilon: 0.003	Test Accuracy = 231 / 10000 = 0.0231
# Epsilon: 0.007	Test Accuracy = 653 / 10000 = 0.0653
# Epsilon: 0.01	Test Accuracy = 978 / 10000 = 0.0978
# Epsilon: 0.05	Test Accuracy = 3321 / 10000 = 0.3321
# Epsilon: 0.1	Test Accuracy = 3809 / 10000 = 0.3809
#
#  Running class=bird slope=1 ...
# Epsilon: 0.003	Test Accuracy = 659 / 10000 = 0.0659
# Epsilon: 0.007	Test Accuracy = 1346 / 10000 = 0.1346
# Epsilon: 0.01	Test Accuracy = 1791 / 10000 = 0.1791
# Epsilon: 0.05	Test Accuracy = 4008 / 10000 = 0.4008
# Epsilon: 0.1	Test Accuracy = 4423 / 10000 = 0.4423
#
#  Running class=bird slope=2 ...
# Epsilon: 0.003	Test Accuracy = 672 / 10000 = 0.0672
# Epsilon: 0.007	Test Accuracy = 1410 / 10000 = 0.141
# Epsilon: 0.01	Test Accuracy = 1843 / 10000 = 0.1843
# Epsilon: 0.05	Test Accuracy = 3912 / 10000 = 0.3912
# Epsilon: 0.1	Test Accuracy = 4264 / 10000 = 0.4264
#
#  Running class=bird slope=5 ...
# Epsilon: 0.003	Test Accuracy = 684 / 10000 = 0.0684
# Epsilon: 0.007	Test Accuracy = 1387 / 10000 = 0.1387
# Epsilon: 0.01	Test Accuracy = 1811 / 10000 = 0.1811
# Epsilon: 0.05	Test Accuracy = 3820 / 10000 = 0.382
# Epsilon: 0.1	Test Accuracy = 4180 / 10000 = 0.418
#
#  Running class=bird slope=10 ...
# Epsilon: 0.003	Test Accuracy = 693 / 10000 = 0.0693
# Epsilon: 0.007	Test Accuracy = 1393 / 10000 = 0.1393
# Epsilon: 0.01	Test Accuracy = 1819 / 10000 = 0.1819
# Epsilon: 0.05	Test Accuracy = 3825 / 10000 = 0.3825
# Epsilon: 0.1	Test Accuracy = 4172 / 10000 = 0.4172
#
#  Running class=bird slope=100 ...
# Epsilon: 0.003	Test Accuracy = 689 / 10000 = 0.0689
# Epsilon: 0.007	Test Accuracy = 1389 / 10000 = 0.1389
# Epsilon: 0.01	Test Accuracy = 1820 / 10000 = 0.182
# Epsilon: 0.05	Test Accuracy = 3817 / 10000 = 0.3817
# Epsilon: 0.1	Test Accuracy = 4155 / 10000 = 0.4155
#  Running class=cat slope=0.5 ...
# Epsilon: 0.003	Test Accuracy = 667 / 10000 = 0.0667
# Epsilon: 0.007	Test Accuracy = 1335 / 10000 = 0.1335
# Epsilon: 0.01	Test Accuracy = 1748 / 10000 = 0.1748
# Epsilon: 0.05	Test Accuracy = 3538 / 10000 = 0.3538
# Epsilon: 0.1	Test Accuracy = 3638 / 10000 = 0.3638
#
#  Running class=cat slope=1 ...
# Epsilon: 0.003	Test Accuracy = 538 / 10000 = 0.0538
# Epsilon: 0.007	Test Accuracy = 1148 / 10000 = 0.1148
# Epsilon: 0.01	Test Accuracy = 1508 / 10000 = 0.1508
# Epsilon: 0.05	Test Accuracy = 3057 / 10000 = 0.3057
# Epsilon: 0.1	Test Accuracy = 3011 / 10000 = 0.3011
#
#  Running class=cat slope=2 ...
# Epsilon: 0.003	Test Accuracy = 477 / 10000 = 0.0477
# Epsilon: 0.007	Test Accuracy = 991 / 10000 = 0.0991
# Epsilon: 0.01	Test Accuracy = 1299 / 10000 = 0.1299
# Epsilon: 0.05	Test Accuracy = 2761 / 10000 = 0.2761
# Epsilon: 0.1	Test Accuracy = 2736 / 10000 = 0.2736
#
#  Running class=cat slope=5 ...
# Epsilon: 0.003	Test Accuracy = 480 / 10000 = 0.048
# Epsilon: 0.007	Test Accuracy = 949 / 10000 = 0.0949
# Epsilon: 0.01	Test Accuracy = 1205 / 10000 = 0.1205
# Epsilon: 0.05	Test Accuracy = 2680 / 10000 = 0.268
# Epsilon: 0.1	Test Accuracy = 2629 / 10000 = 0.2629
#
#  Running class=cat slope=10 ...
# Epsilon: 0.003	Test Accuracy = 453 / 10000 = 0.0453
# Epsilon: 0.007	Test Accuracy = 917 / 10000 = 0.0917
# Epsilon: 0.01	Test Accuracy = 1190 / 10000 = 0.119
# Epsilon: 0.05	Test Accuracy = 2651 / 10000 = 0.2651
# Epsilon: 0.1	Test Accuracy = 2594 / 10000 = 0.2594
#
#  Running class=cat slope=100 ...
# Epsilon: 0.003	Test Accuracy = 438 / 10000 = 0.0438
# Epsilon: 0.007	Test Accuracy = 901 / 10000 = 0.0901
# Epsilon: 0.01	Test Accuracy = 1183 / 10000 = 0.1183
# Epsilon: 0.05	Test Accuracy = 2608 / 10000 = 0.2608
# Epsilon: 0.1	Test Accuracy = 2593 / 10000 = 0.2593
#  Running class=deer slope=0.5 ...
# Epsilon: 0.003	Test Accuracy = 880 / 10000 = 0.088
# Epsilon: 0.007	Test Accuracy = 1837 / 10000 = 0.1837
# Epsilon: 0.01	Test Accuracy = 2484 / 10000 = 0.2484
# Epsilon: 0.05	Test Accuracy = 5185 / 10000 = 0.5185
# Epsilon: 0.1	Test Accuracy = 5302 / 10000 = 0.5302
#
#  Running class=deer slope=1 ...
# Epsilon: 0.003	Test Accuracy = 571 / 10000 = 0.0571
# Epsilon: 0.007	Test Accuracy = 1225 / 10000 = 0.1225
# Epsilon: 0.01	Test Accuracy = 1620 / 10000 = 0.162
# Epsilon: 0.05	Test Accuracy = 3956 / 10000 = 0.3956
# Epsilon: 0.1	Test Accuracy = 4069 / 10000 = 0.4069
#
#  Running class=deer slope=2 ...
# Epsilon: 0.003	Test Accuracy = 395 / 10000 = 0.0395
# Epsilon: 0.007	Test Accuracy = 884 / 10000 = 0.0884
# Epsilon: 0.01	Test Accuracy = 1188 / 10000 = 0.1188
# Epsilon: 0.05	Test Accuracy = 3146 / 10000 = 0.3146
# Epsilon: 0.1	Test Accuracy = 3352 / 10000 = 0.3352
#
#  Running class=deer slope=5 ...
# Epsilon: 0.003	Test Accuracy = 351 / 10000 = 0.0351
# Epsilon: 0.007	Test Accuracy = 742 / 10000 = 0.0742
# Epsilon: 0.01	Test Accuracy = 1002 / 10000 = 0.1002
# Epsilon: 0.05	Test Accuracy = 2791 / 10000 = 0.2791
# Epsilon: 0.1	Test Accuracy = 3017 / 10000 = 0.3017
#
#  Running class=deer slope=10 ...
# Epsilon: 0.003	Test Accuracy = 330 / 10000 = 0.033
# Epsilon: 0.007	Test Accuracy = 714 / 10000 = 0.0714
# Epsilon: 0.01	Test Accuracy = 957 / 10000 = 0.0957
# Epsilon: 0.05	Test Accuracy = 2703 / 10000 = 0.2703
# Epsilon: 0.1	Test Accuracy = 2924 / 10000 = 0.2924
#
#  Running class=deer slope=100 ...
# Epsilon: 0.003	Test Accuracy = 322 / 10000 = 0.0322
# Epsilon: 0.007	Test Accuracy = 702 / 10000 = 0.0702
# Epsilon: 0.01	Test Accuracy = 928 / 10000 = 0.0928
# Epsilon: 0.05	Test Accuracy = 2631 / 10000 = 0.2631
# Epsilon: 0.1	Test Accuracy = 2878 / 10000 = 0.2878
#  Running class=dog slope=0.5 ...
# Epsilon: 0.003	Test Accuracy = 45 / 10000 = 0.0045
# Epsilon: 0.007	Test Accuracy = 103 / 10000 = 0.0103
# Epsilon: 0.01	Test Accuracy = 159 / 10000 = 0.0159
# Epsilon: 0.05	Test Accuracy = 853 / 10000 = 0.0853
# Epsilon: 0.1	Test Accuracy = 1249 / 10000 = 0.1249
#
#  Running class=dog slope=1 ...
# Epsilon: 0.003	Test Accuracy = 266 / 10000 = 0.0266
# Epsilon: 0.007	Test Accuracy = 634 / 10000 = 0.0634
# Epsilon: 0.01	Test Accuracy = 868 / 10000 = 0.0868
# Epsilon: 0.05	Test Accuracy = 2049 / 10000 = 0.2049
# Epsilon: 0.1	Test Accuracy = 2437 / 10000 = 0.2437
#
#  Running class=dog slope=2 ...
# Epsilon: 0.003	Test Accuracy = 403 / 10000 = 0.0403
# Epsilon: 0.007	Test Accuracy = 808 / 10000 = 0.0808
# Epsilon: 0.01	Test Accuracy = 1051 / 10000 = 0.1051
# Epsilon: 0.05	Test Accuracy = 2251 / 10000 = 0.2251
# Epsilon: 0.1	Test Accuracy = 2568 / 10000 = 0.2568
#
#  Running class=dog slope=5 ...
# Epsilon: 0.003	Test Accuracy = 421 / 10000 = 0.0421
# Epsilon: 0.007	Test Accuracy = 820 / 10000 = 0.082
# Epsilon: 0.01	Test Accuracy = 1075 / 10000 = 0.1075
# Epsilon: 0.05	Test Accuracy = 2261 / 10000 = 0.2261
# Epsilon: 0.1	Test Accuracy = 2496 / 10000 = 0.2496
#
#  Running class=dog slope=10 ...
# Epsilon: 0.003	Test Accuracy = 427 / 10000 = 0.0427
# Epsilon: 0.007	Test Accuracy = 834 / 10000 = 0.0834
# Epsilon: 0.01	Test Accuracy = 1059 / 10000 = 0.1059
# Epsilon: 0.05	Test Accuracy = 2283 / 10000 = 0.2283
# Epsilon: 0.1	Test Accuracy = 2514 / 10000 = 0.2514
#
#  Running class=dog slope=100 ...
# Epsilon: 0.003	Test Accuracy = 435 / 10000 = 0.0435
# Epsilon: 0.007	Test Accuracy = 838 / 10000 = 0.0838
# Epsilon: 0.01	Test Accuracy = 1078 / 10000 = 0.1078
# Epsilon: 0.05	Test Accuracy = 2258 / 10000 = 0.2258
# Epsilon: 0.1	Test Accuracy = 2508 / 10000 = 0.2508
#  Running class=frog slope=0.5 ...
# Epsilon: 0.003	Test Accuracy = 740 / 10000 = 0.074
# Epsilon: 0.007	Test Accuracy = 1669 / 10000 = 0.1669
# Epsilon: 0.01	Test Accuracy = 2238 / 10000 = 0.2238
# Epsilon: 0.05	Test Accuracy = 5139 / 10000 = 0.5139
# Epsilon: 0.1	Test Accuracy = 5673 / 10000 = 0.5673
#
#  Running class=frog slope=1 ...
# Epsilon: 0.003	Test Accuracy = 555 / 10000 = 0.0555
# Epsilon: 0.007	Test Accuracy = 1227 / 10000 = 0.1227
# Epsilon: 0.01	Test Accuracy = 1716 / 10000 = 0.1716
# Epsilon: 0.05	Test Accuracy = 4225 / 10000 = 0.4225
# Epsilon: 0.1	Test Accuracy = 4716 / 10000 = 0.4716
#
#  Running class=frog slope=2 ...
# Epsilon: 0.003	Test Accuracy = 441 / 10000 = 0.0441
# Epsilon: 0.007	Test Accuracy = 1008 / 10000 = 0.1008
# Epsilon: 0.01	Test Accuracy = 1394 / 10000 = 0.1394
# Epsilon: 0.05	Test Accuracy = 3729 / 10000 = 0.3729
# Epsilon: 0.1	Test Accuracy = 4268 / 10000 = 0.4268
#
#  Running class=frog slope=5 ...
# Epsilon: 0.003	Test Accuracy = 386 / 10000 = 0.0386
# Epsilon: 0.007	Test Accuracy = 888 / 10000 = 0.0888
# Epsilon: 0.01	Test Accuracy = 1217 / 10000 = 0.1217
# Epsilon: 0.05	Test Accuracy = 3480 / 10000 = 0.348
# Epsilon: 0.1	Test Accuracy = 4052 / 10000 = 0.4052
#
#  Running class=frog slope=10 ...
# Epsilon: 0.003	Test Accuracy = 377 / 10000 = 0.0377
# Epsilon: 0.007	Test Accuracy = 850 / 10000 = 0.085
# Epsilon: 0.01	Test Accuracy = 1179 / 10000 = 0.1179
# Epsilon: 0.05	Test Accuracy = 3398 / 10000 = 0.3398
# Epsilon: 0.1	Test Accuracy = 3970 / 10000 = 0.397
#
#  Running class=frog slope=100 ...
# Epsilon: 0.003	Test Accuracy = 366 / 10000 = 0.0366
# Epsilon: 0.007	Test Accuracy = 828 / 10000 = 0.0828
# Epsilon: 0.01	Test Accuracy = 1143 / 10000 = 0.1143
# Epsilon: 0.05	Test Accuracy = 3358 / 10000 = 0.3358
# Epsilon: 0.1	Test Accuracy = 3930 / 10000 = 0.393
#  Running class=horse slope=0.5 ...
# Epsilon: 0.003	Test Accuracy = 138 / 10000 = 0.0138
# Epsilon: 0.007	Test Accuracy = 357 / 10000 = 0.0357
# Epsilon: 0.01	Test Accuracy = 525 / 10000 = 0.0525
# Epsilon: 0.05	Test Accuracy = 2670 / 10000 = 0.267
# Epsilon: 0.1	Test Accuracy = 3812 / 10000 = 0.3812
#
#  Running class=horse slope=1 ...
# Epsilon: 0.003	Test Accuracy = 326 / 10000 = 0.0326
# Epsilon: 0.007	Test Accuracy = 781 / 10000 = 0.0781
# Epsilon: 0.01	Test Accuracy = 1138 / 10000 = 0.1138
# Epsilon: 0.05	Test Accuracy = 3781 / 10000 = 0.3781
# Epsilon: 0.1	Test Accuracy = 4753 / 10000 = 0.4753
#
#  Running class=horse slope=2 ...
# Epsilon: 0.003	Test Accuracy = 364 / 10000 = 0.0364
# Epsilon: 0.007	Test Accuracy = 934 / 10000 = 0.0934
# Epsilon: 0.01	Test Accuracy = 1331 / 10000 = 0.1331
# Epsilon: 0.05	Test Accuracy = 3917 / 10000 = 0.3917
# Epsilon: 0.1	Test Accuracy = 4778 / 10000 = 0.4778
#
#  Running class=horse slope=5 ...
# Epsilon: 0.003	Test Accuracy = 401 / 10000 = 0.0401
# Epsilon: 0.007	Test Accuracy = 1009 / 10000 = 0.1009
# Epsilon: 0.01	Test Accuracy = 1393 / 10000 = 0.1393
# Epsilon: 0.05	Test Accuracy = 3935 / 10000 = 0.3935
# Epsilon: 0.1	Test Accuracy = 4767 / 10000 = 0.4767
#
#  Running class=horse slope=10 ...
# Epsilon: 0.003	Test Accuracy = 421 / 10000 = 0.0421
# Epsilon: 0.007	Test Accuracy = 1022 / 10000 = 0.1022
# Epsilon: 0.01	Test Accuracy = 1404 / 10000 = 0.1404
# Epsilon: 0.05	Test Accuracy = 3918 / 10000 = 0.3918
# Epsilon: 0.1	Test Accuracy = 4737 / 10000 = 0.4737
#
#  Running class=horse slope=100 ...
# Epsilon: 0.003	Test Accuracy = 427 / 10000 = 0.0427
# Epsilon: 0.007	Test Accuracy = 1029 / 10000 = 0.1029
# Epsilon: 0.01	Test Accuracy = 1421 / 10000 = 0.1421
# Epsilon: 0.05	Test Accuracy = 3918 / 10000 = 0.3918
# Epsilon: 0.1	Test Accuracy = 4710 / 10000 = 0.471
#  Running class=ship slope=0.5 ...
# Epsilon: 0.003	Test Accuracy = 431 / 10000 = 0.0431
# Epsilon: 0.007	Test Accuracy = 947 / 10000 = 0.0947
# Epsilon: 0.01	Test Accuracy = 1243 / 10000 = 0.1243
# Epsilon: 0.05	Test Accuracy = 2871 / 10000 = 0.2871
# Epsilon: 0.1	Test Accuracy = 2884 / 10000 = 0.2884
#
#  Running class=ship slope=1 ...
# Epsilon: 0.003	Test Accuracy = 310 / 10000 = 0.031
# Epsilon: 0.007	Test Accuracy = 686 / 10000 = 0.0686
# Epsilon: 0.01	Test Accuracy = 963 / 10000 = 0.0963
# Epsilon: 0.05	Test Accuracy = 2383 / 10000 = 0.2383
# Epsilon: 0.1	Test Accuracy = 2363 / 10000 = 0.2363
#
#  Running class=ship slope=2 ...
# Epsilon: 0.003	Test Accuracy = 269 / 10000 = 0.0269
# Epsilon: 0.007	Test Accuracy = 606 / 10000 = 0.0606
# Epsilon: 0.01	Test Accuracy = 820 / 10000 = 0.082
# Epsilon: 0.05	Test Accuracy = 2147 / 10000 = 0.2147
# Epsilon: 0.1	Test Accuracy = 2129 / 10000 = 0.2129
#
#  Running class=ship slope=5 ...
# Epsilon: 0.003	Test Accuracy = 239 / 10000 = 0.0239
# Epsilon: 0.007	Test Accuracy = 565 / 10000 = 0.0565
# Epsilon: 0.01	Test Accuracy = 769 / 10000 = 0.0769
# Epsilon: 0.05	Test Accuracy = 1991 / 10000 = 0.1991
# Epsilon: 0.1	Test Accuracy = 1986 / 10000 = 0.1986
#
#  Running class=ship slope=10 ...
# Epsilon: 0.003	Test Accuracy = 232 / 10000 = 0.0232
# Epsilon: 0.007	Test Accuracy = 549 / 10000 = 0.0549
# Epsilon: 0.01	Test Accuracy = 760 / 10000 = 0.076
# Epsilon: 0.05	Test Accuracy = 1964 / 10000 = 0.1964
# Epsilon: 0.1	Test Accuracy = 1958 / 10000 = 0.1958
#
#  Running class=ship slope=100 ...
# Epsilon: 0.003	Test Accuracy = 237 / 10000 = 0.0237
# Epsilon: 0.007	Test Accuracy = 541 / 10000 = 0.0541
# Epsilon: 0.01	Test Accuracy = 752 / 10000 = 0.0752
# Epsilon: 0.05	Test Accuracy = 1945 / 10000 = 0.1945
# Epsilon: 0.1	Test Accuracy = 1914 / 10000 = 0.1914
#  Running class=truck slope=0.5 ...
# Epsilon: 0.003	Test Accuracy = 197 / 10000 = 0.0197
# Epsilon: 0.007	Test Accuracy = 446 / 10000 = 0.0446
# Epsilon: 0.01	Test Accuracy = 613 / 10000 = 0.0613
# Epsilon: 0.05	Test Accuracy = 2047 / 10000 = 0.2047
# Epsilon: 0.1	Test Accuracy = 2989 / 10000 = 0.2989
#
#  Running class=truck slope=1 ...
# Epsilon: 0.003	Test Accuracy = 265 / 10000 = 0.0265
# Epsilon: 0.007	Test Accuracy = 608 / 10000 = 0.0608
# Epsilon: 0.01	Test Accuracy = 826 / 10000 = 0.0826
# Epsilon: 0.05	Test Accuracy = 2523 / 10000 = 0.2523
# Epsilon: 0.1	Test Accuracy = 3300 / 10000 = 0.33
#
#  Running class=truck slope=2 ...
# Epsilon: 0.003	Test Accuracy = 295 / 10000 = 0.0295
# Epsilon: 0.007	Test Accuracy = 661 / 10000 = 0.0661
# Epsilon: 0.01	Test Accuracy = 880 / 10000 = 0.088
# Epsilon: 0.05	Test Accuracy = 2582 / 10000 = 0.2582
# Epsilon: 0.1	Test Accuracy = 3320 / 10000 = 0.332
#
#  Running class=truck slope=5 ...
# Epsilon: 0.003	Test Accuracy = 305 / 10000 = 0.0305
# Epsilon: 0.007	Test Accuracy = 681 / 10000 = 0.0681
# Epsilon: 0.01	Test Accuracy = 887 / 10000 = 0.0887
# Epsilon: 0.05	Test Accuracy = 2606 / 10000 = 0.2606
# Epsilon: 0.1	Test Accuracy = 3319 / 10000 = 0.3319
#
#  Running class=truck slope=10 ...
# Epsilon: 0.003	Test Accuracy = 304 / 10000 = 0.0304
# Epsilon: 0.007	Test Accuracy = 677 / 10000 = 0.0677
# Epsilon: 0.01	Test Accuracy = 890 / 10000 = 0.089
# Epsilon: 0.05	Test Accuracy = 2594 / 10000 = 0.2594
# Epsilon: 0.1	Test Accuracy = 3308 / 10000 = 0.3308
#
#  Running class=truck slope=100 ...
# Epsilon: 0.003	Test Accuracy = 304 / 10000 = 0.0304
# Epsilon: 0.007	Test Accuracy = 669 / 10000 = 0.0669
# Epsilon: 0.01	Test Accuracy = 889 / 10000 = 0.0889
# Epsilon: 0.05	Test Accuracy = 2578 / 10000 = 0.2578
# Epsilon: 0.1	Test Accuracy = 3286 / 10000 = 0.3286

# %%
np.save(f'/gdrive/My Drive/Tmp/Targeted/CIFAR_slopes.npy', all_all_accuracies)

# %%
all_res = np.array(all_all_accuracies)
all_res_m = all_res.mean(axis=0).T

# %%
fig =plt.figure(figsize=(5,5))
for idx in range(len(all_res_m)):
    plt.plot(all_res_m[:,idx], symbs[idx])

#     plt.plot(epsilons, np.array(all_accuracies).T, "*-")
plt.yticks(np.arange(0, .5, step=0.1))
plt.xticks(np.arange(0, 5, step=1), epsilons)
plt.title(f"Accuracy vs Epsilon (Avg. over digits)")
plt.xlabel("Epsilon")
plt.ylabel("Accuracy")
plt.legend(slopes)
plt.show()
fig.savefig(f'/gdrive/My Drive/Tmp/Targeted/CIFAR_avg.png')

# %%
# torch.save(all_accuracies,'/gdrive/My Drive/Tmp/accs_CIFAR_Targeted.npy')

# %%
model_1 = Net(1).to(device)
model_1.load_state_dict(torch.load(pretrained_model, map_location='cpu'))
model_1.eval()

model_2 = Net(100).to(device)
model_2.load_state_dict(torch.load(pretrained_model, map_location='cpu'))
model_2.eval()


# Run test for each epsilon
def_examples_1 = []
def_examples_2 = []

eps = .1

myTarget = torch.tensor([0]) #torch.randint(10, (1,1)).squeeze(0)        

# test_loader_2 = torch.utils.data.DataLoader(cifar10_test, batch_size=1,
#                                         shuffle=False, num_workers=1)

_, ex = test(model_1, device, test_loader, eps, myTarget)
def_examples_1.append(ex)

_, ex = test(model_2, device, test_loader, eps, myTarget)
def_examples_2.append(ex)
# Out:
# Epsilon: 0.1	Test Accuracy = 2716 / 10000 = 0.2716
# Epsilon: 0.1	Test Accuracy = 2994 / 10000 = 0.2994

# %%
x,y = (img, label)

# %%
y
# Out:
# tensor([3])

# %%
# Plot several examples of adversarial samples at each epsilon
cnt = 0
plt.figure(figsize=(8,10))
for j in range(len(def_examples_1[0])):
    cnt += 1
    plt.subplot(1,len(def_examples_1[0]),cnt)
    plt.xticks([], [])
    plt.yticks([], [])
    if j == 0:
        plt.ylabel("Eps: {}".format(eps), fontsize=14)
    orig,adv,ex = def_examples_1[0][j]
    plt.title("{} -> {}".format(classes[orig], classes[adv]))
    plt.imshow(ex.transpose(1,2,0), cmap="gray")
plt.tight_layout()
plt.show()

cnt = 0
plt.figure(figsize=(8,10))
for j in range(len(def_examples_2[0])):
    cnt += 1
    plt.subplot(1,len(def_examples_2[0]),cnt)
    plt.xticks([], [])
    plt.yticks([], [])
    if j == 0:
        plt.ylabel("Eps: {}".format(eps), fontsize=14)
    orig,adv,ex = def_examples_2[0][j]
    plt.title("{} -> {}".format(classes[orig], classes[adv]))
    plt.imshow(ex.transpose(1,2,0), cmap="gray")
plt.tight_layout()
plt.show()
