# %%
from matplotlib import pyplot as plt

# %%
all_all_accuracies.shape
# Out:
# (10, 6, 5)

# %%
import numpy as np
all_all_accuracies = np.load('./CIFAR_slopes.npy', allow_pickle=True)

# %%
fig = plt.figure(figsize=(5,5))
attackNames = ['FGSM', 'BIM', 'StepLL', 'RFGSM', 'PGD',  'DeepFool']

res = all_accuracies.mean(axis=2)
slopes   = [.5, 1, 2, 5, 10, 100]

symbs = ['*-', 'o-',  's-', 'd-', '+-', 'x-', '^-', '<-']
for idx in range(1,len(res)):
    plt.plot(res[idx,:]/100, symbs[idx])
    
#     plt.plot(epsilons, np.array(all_accuracies).T, "*-")
plt.yticks(np.arange(0, 1.1, step=0.1))
plt.xticks(np.arange(0, res.shape[0], step=1), slopes)
plt.title("Accuracy vs Slope")
plt.xlabel("Slope")
plt.ylabel("Accuracy")
plt.legend(attackNames)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-34-442252b0a856> in <module>
#       7 symbs = ['*-', 'o-',  's-', 'd-', '+-', 'x-', '^-', '<-']
#       8 for idx in range(1,len(res)):
# ----> 9     plt.plot(res[idx,:]/100, symbs[idx])
#      10
#      11 #     plt.plot(epsilons, np.array(all_accuracies).T, "*-")
#
# IndexError: list index out of range

# %%
for attIdx, att in enumerate(attackNames):
  fig = plt.figure(figsize=(5,5))
  res = all_accuracies[attIdx]

  symbs = ['*-', 'o-',  's-', 'd-', '+-', 'x-', '^-', '<-']
  for idx in range(len(res)):
      plt.plot(res[idx,:]/100, symbs[idx])
      
  #     plt.plot(epsilons, np.array(all_accuracies).T, "*-")
  plt.yticks(np.arange(0, 1.1, step=0.1))
  plt.xticks(np.arange(0, len(epsilons), step=1), epsilons)
  plt.title(f"Accuracy vs Epsilon - {att}")
  plt.xlabel("Epsilon")
  plt.ylabel("Accuracy")
  plt.legend(slopes)
  plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-4afbbde7d723> in <module>
#       1 for attIdx, att in enumerate(attackNames):
#       2   fig = plt.figure(figsize=(5,5))
# ----> 3   res = all_accuracies[attIdx]
#       4
#       5   symbs = ['*-', 'o-',  's-', 'd-', '+-', 'x-', '^-', '<-']
#
# TypeError: 'int' object is not subscriptable

# %%
# all_res = np.array(all_all_accuracies)
all_res_m = all_res_new.mean(axis=0)

# %%
all_res_m.shape
# Out:
# (6, 6)

# %%
epsilons = [0, 0.003, 0.007, 0.01, 0.05, 0.1 ]
slopes   = [.5, 1, 2, 5, 10, 100]
symbs = ['*-', 'o-', 's-', 'd-', '+-', 'x-', '^-', '<-']

fig =plt.figure(figsize=(5,5))
for idx in range(len(all_res_m)):
    plt.plot(all_res_m[idx,:], symbs[idx])

#     plt.plot(epsilons, np.array(all_accuracies).T, "*-")
plt.yticks(np.arange(0, .5, step=0.1))
plt.xticks(np.arange(0, 6, step=1), epsilons)
plt.title(f"Accuracy vs Epsilon (Avg. over classes)")
plt.xlabel("Epsilon")
plt.ylabel("Accuracy")
plt.legend(slopes)
fig.savefig(f'./CIFAR_avg.png')

plt.show()

# %%
all_res_m[idx,:]
# Out:
# array([0.03866, 0.0834 , 0.11264, 0.28934, 0.32802])

# %%
[0, all_res_m[idx,:].tolist()]
# Out:
# [0,
#  [0.03559,
#   0.07889999999999998,
#   0.10762000000000001,
#   0.28667999999999993,
#   0.33567]]

# %%
all_res.shape
# Out:
# (10, 6, 5)

# %%
all_res_new = np.zeros((10,6,6))

# %%
all_res_new[:,:,1:] = all_res

# %%
all_res_new[:,:,0] = 0

# %%
all_res_new.shape
# Out:
# (10, 6, 6)

# %%
classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

for j in range(10):
    all_res_m = all_res_new[j,:,:]
    fig =plt.figure(figsize=(5,5))
    for idx in range(len(all_res_m)):
        plt.plot(all_res_m[idx,:], symbs[idx])

    #     plt.plot(epsilons, np.array(all_accuracies).T, "*-")
    plt.yticks(np.arange(0, .5, step=0.1))
    plt.xticks(np.arange(0, 6, step=1), epsilons)
    plt.title(f"Accuracy vs Epsilon (Converting to {classes[j]})")
    plt.xlabel("Epsilon")
    plt.ylabel("Accuracy")
    plt.legend(slopes)
    fig.savefig(f'.plot-{classes[j]}.png')
    plt.show()

# %%
x = np.arange(-100,100,1)
for a in np.arange(0,10,1):
    y = np.maximum(0,a*x)
    plt.plot(x,y)

# %%
x = np.arange(-100,100,1)
for a in np.arange(0,10,1):
    y = a*np.maximum(0,x)
    plt.plot(x,y)
